# %%
#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#plt.plot(BGt1,Bkgrd,'ro')

# 10 minute trial
Ag_10min = np.array(data['AG 10 min'])
Ag_10min = Ag_10min[~np.isnan(Ag_10min)]

# 10 minute trial times
t10 = np.array(data['t10'])
t10 = t10[~np.isnan(t10)]

plt.plot(t10,Ag_10min,'b.',label='10 Minute Charging Time')
plt.errorbar(t10,Ag_10min,xerr = 0,yerr = np.sqrt(Ag_10min), fmt = None, color = 'b')

# 5 minute trial
Ag_5min = np.array(data['Ag 5min'])
Ag_5min = Ag_5min[~np.isnan(Ag_5min)]

# 5 minute trial times 
t5 = np.array(data['t5'])
t5 = t5[~np.isnan(t5)]

plt.plot(t5,Ag_5min,'m.',label='5 Minute Charging Time')
plt.errorbar(t5,Ag_5min,xerr = 0,yerr = np.sqrt(Ag_5min), fmt = None, color = 'm')

# 2 minute trial counts
Ag_2min = np.array(data['Ag 2min'])
Ag_2min = Ag_2min[~np.isnan(Ag_2min)]

# 2 minute trial times
t2 = np.array(data['t2'])
t2 = t2[~np.isnan(t2)]

plt.plot(t2,Ag_2min,'g.',label='2 Minute Charging Time')
plt.errorbar(t2,Ag_2min,xerr = 0,yerr = np.sqrt(Ag_2min), fmt = None, color = 'g')

# 1 minute trial counts
Ag_1min = np.array(data['Ag 1min'])
Ag_1min = Ag_1min[~np.isnan(Ag_1min)]

# 1 minute trial times
t1 = np.array(data['t1'])
t1 = t1[~np.isnan(t1)]

plt.plot(t1,Ag_1min,'y.',label='1 Minute Charging Time')
plt.errorbar(t1,Ag_1min,xerr = 0,yerr = np.sqrt(Ag_1min), fmt = None, color = 'y')

# 20 seconds trial counts
Ag_20 = np.array(data['20 sec'])
Ag_20 = Ag_20[~np.isnan(Ag_20)]
 
# 20 seconds trial times
t20s = np.array(data['t20s'])
t20s = t20s[~np.isnan(t20s)]  

plt.plot(t20s,Ag_20, 'c.',label='20 Second Charging Time')  
plt.errorbar(t20s,Ag_20,xerr = 0,yerr = np.sqrt(Ag_20), fmt = None, color = 'c')

# 10 seconds trial counts
Ag_10 = np.array(data['10 sec'])
Ag_10 = Ag_10[~np.isnan(Ag_10)]

# 10 seconds trial times
t10s = np.array(data['Auto'])
t10s = t10s[~np.isnan(t10s)]  

plt.plot(t10s,Ag_10, 'r.',label='10 Second Charging Time')  
plt.errorbar(t10s,Ag_10,xerr = 0,yerr = np.sqrt(Ag_10), fmt = None, color = 'r')
plt.ylabel('Count Rate (counts/5s)',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

plt.legend(fontsize=14)
pylab.savefig('silverdecays.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# /Users/kaylarodriguez/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:2813: MatplotlibDeprecationWarning: Use of None object as fmt keyword argument to suppress plotting of data values is deprecated since 1.4; use the string "none" instead.
#   warnings.warn(msg, mplDeprecation, stacklevel=1)

# %%
#***********************************************************************
# 5 minute data
#***********************************************************************


#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize']        = 7,7/1.62
pylab.rcParams['figure.autolayout']     = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#background log scale
bk = np.log(Bkgrd)
bksubtrt = np.mean(bk)

# 10 minute trial
Ag_5min = np.array(data['Ag 5min'])
Ag_5min = Ag_5min[~np.isnan(Ag_5min)]

#convert to log scale
Ag_5_ln = np.log(Ag_5min)#-bksubtrt

# 10 minute trial times
t5 = np.array(data['t5'])
t5 = t5[~np.isnan(t5)]

plt.plot(t5,Ag_5_ln, 'm.') 

plt.ylabel('Count Rate',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

#little t parameters
lttet = t5[0:13]
lttey = Ag_5_ln[0:13]

print(curve_fit(fit,lttet,lttey))

m1 = curve_fit(fit,lttet,lttey)[0][0]
b1 = curve_fit(fit,lttet,lttey)[0][1]

print(curve_fit(fit,lttet,lttey))

newfit1 = np.linspace(0,100,20)

#change big t parameters
bigt = t5[20:62]
bigy = Ag_5_ln[20:62]

m2 = curve_fit(fit,bigt,bigy)[0][0]
b2 = curve_fit(fit,bigt,bigy)[0][1]

print(curve_fit(fit,bigt,bigy))

newfit2 = np.linspace(100,330,20)

plt.plot(newfit1,fit(newfit1,m1,b1),'r-')

plt.plot(newfit2,fit(newfit2,m2,b2),'g-')

print(1/m1)
print(1/m2)

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
# Out:
# (array([-0.02250665,  6.03654109]), array([[ 1.77943498e-06, -7.11773991e-05],
#        [-7.11773991e-05,  3.46989819e-03]]))
# (array([-0.02250665,  6.03654109]), array([[ 1.77943498e-06, -7.11773991e-05],
#        [-7.11773991e-05,  3.46989819e-03]]))
# (array([-0.00669785,  4.74612827]), array([[ 3.04660284e-07, -6.32170093e-05],
#        [-6.32170093e-05,  1.41324291e-02]]))
# -44.43131571420542
# -149.30175218371213
# halflifes
# -30.797441215870275
# -103.48808857879972

# %%
#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#background log scale
bk = np.log(Bkgrd)
bksubtrt = np.mean(bk)

# 10 minute trial
Ag_10min = np.array(data['AG 10 min'])
Ag_10min = Ag_10min[~np.isnan(Ag_10min)]

#convert to log scale
Ag_10_ln = np.log(Ag_10min)

# 10 minute trial times
t10 = np.array(data['t10'])
t10 = t10[~np.isnan(t10)]

newt = t10[0:40]
newy = Ag_10_ln[0:40]-bksubtrt 
newt2 = t10[100:600]
newy2 = Ag_10_ln[100:600]-bksubtrt 

plt.plot(t10,Ag_10_ln-bksubtrt , 'b.') 

plt.ylabel('Count Rate',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

print(curve_fit(fit,newt,newy))

newfit1 = np.linspace(0,100,20)

m1 = curve_fit(fit,newt,newy)[0][0]
b1 = curve_fit(fit,newt,newy)[0][1]

newfit1 = np.linspace(0,100,20)

m2 = curve_fit(fit,newt2,newy2)[0][0]
b2 = curve_fit(fit,newt2,newy2)[0][1]

print(1/m1)
print(1/m2)
newfit2 = np.linspace(100,630,20)
plt.plot(newfit1,fit(newfit1,m1,b1),'r')
plt.plot(newfit2,fit(newfit2,m2,b2),'c')

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
# Out:
# (array([-0.0110305 ,  3.15577034]), array([[ 3.93109622e-07, -4.22592847e-05],
#        [-4.22592847e-05,  5.85241959e-03]]))
# -90.6577360881862
# -276.0407840016154
# halflifes
# -62.839154165473865
# -191.33689115027656

# %%
#***********************************************************************
# 10 minute data -> with corrected background
#***********************************************************************


#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#average the background
avgBk = np.mean(Bkgrd)

# 10 minute trial
Ag_10min = np.array(data['AG 10 min'])
Ag_10min = Ag_10min[~np.isnan(Ag_10min)]


# 10 minute trial times
t10 = np.array(data['t10'])
t10 = t10[~np.isnan(t10)]

#corrected counts
crrct = Ag_10min #- avgBk

for i in range(len(crrct)):
    t10[crrct<0] = 0
    crrct[crrct<0] = 0
    t10n = t10[t10>0]
    countn = crrct[crrct>0]
        
#convert to log scale
Ag_10_ln = np.log(countn)

plt.plot(t10n,Ag_10_ln, 'b.') 

plt.ylabel('Count Rate',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

#little t parameters
lttet = t10n[0:20]
lttey = Ag_10_ln[0:20]

print(curve_fit(fit,lttet,lttey))

m1 = curve_fit(fit,lttet,lttey)[0][0]
b1 = curve_fit(fit,lttet,lttey)[0][1]

print(curve_fit(fit,lttet,lttey))

newfit1 = np.linspace(0,100,20)

#change big t parameters
bigt = t10n[20:96]
bigy = Ag_10_ln[20:96]

m2 = curve_fit(fit,bigt,bigy)[0][0]
b2 = curve_fit(fit,bigt,bigy)[0][1]

print(curve_fit(fit,bigt,bigy))

newfit2 = np.linspace(100,600,20)

plt.plot(newfit1,fit(newfit1,m1,b1),'r-')

plt.plot(newfit2,fit(newfit2,m2,b2),'g-')

cov = curve_fit(fit,t10,Ag_10_ln) [1]
var = np.diag(cov)
std = np.sqrt(var)
print('std')
print(std)

print(1/m1)
print(1/m2)
print(np.exp(b1))
print(np.exp(b2))

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
# Out:
# (array([-0.01815463,  5.86567081]), array([[ 5.89946158e-07, -3.39219043e-05],
#        [-3.39219043e-05,  2.44090225e-03]]))
# (array([-0.01815463,  5.86567081]), array([[ 5.89946158e-07, -3.39219043e-05],
#        [-3.39219043e-05,  2.44090225e-03]]))
# (array([-0.00461017,  4.45366164]), array([[ 6.86032426e-08, -2.04094647e-05],
#        [-2.04094647e-05,  6.89719851e-03]]))
# std
# [0.00017266 0.06342809]
# -55.08237626488318
# -216.91171092450725
# 352.7186836137118
# 85.94105416849978
# halflifes
# -38.18019380654582
# -150.35174085775608

# %%
#***********************************************************************
# 2 minute data
#***********************************************************************


#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize']        = 7,7/1.62
pylab.rcParams['figure.autolayout']     = False
pylab.rcParams.update({'axes.labelsize' : 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize' : 20.0})

pylab.rcParams.update({'ytick.direction' : 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction' : 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#background log scale
bk = np.log(Bkgrd)
bksubtrt = np.mean(bk)

print(bksubtrt)
# 5 minute trial
Ag_2min = np.array(data['Ag 2min'])
Ag_2min = Ag_2min[~np.isnan(Ag_2min)]

#convert to log scale
Ag_2_ln = np.log(Ag_2min)#-bksubtrt

# 2 minute trial times
t2 = np.array(data['t2'])
t2 = t2[~np.isnan(t2)]

plt.plot(t2,Ag_2_ln, 'g.') 

plt.ylabel('Count Rate',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

#little t parameters
lttet = t2[0:13]
lttey = Ag_2_ln[0:13]

print(curve_fit(fit,lttet,lttey))

m1 = curve_fit(fit,lttet,lttey)[0][0]
b1 = curve_fit(fit,lttet,lttey)[0][1]

print(curve_fit(fit,lttet,lttey))

newfit1 = np.linspace(0,100,20)

#change big t parameters
bigt = t2[17:62]
bigy = Ag_2_ln[17:62]

m2 = curve_fit(fit,bigt,bigy)[0][0]
b2 = curve_fit(fit,bigt,bigy)[0][1]

print(curve_fit(fit,bigt,bigy))

newfit2 = np.linspace(100,220,20)

plt.plot(newfit1,fit(newfit1,m1,b1),'r-')

plt.plot(newfit2,fit(newfit2,m2,b2),'g-')

print(1/m1)
print(1/m2)

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
# Out:
# 2.3279018640087674
# (array([-0.02268372,  5.8250056 ]), array([[ 1.83216607e-06, -7.32866423e-05],
#        [-7.32866423e-05,  3.57272376e-03]]))
# (array([-0.02268372,  5.8250056 ]), array([[ 1.83216607e-06, -7.32866423e-05],
#        [-7.32866423e-05,  3.57272376e-03]]))
# (array([-0.00810161,  4.40108878]), array([[ 1.40460419e-06, -2.14202141e-04],
#        [-2.14202141e-04,  3.43484256e-02]]))
# -44.084486340469454
# -123.43228884405252
# halflifes
# -30.557037413329823
# -85.5567430023158

# %%
#***********************************************************************
# 1 minute data
#***********************************************************************


#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#background log scale
bk = np.log(Bkgrd)
bksubtrt = np.mean(bk)
print(bksubtrt)

# 1 minute trial
Ag_1min = np.array(data['Ag 1min'])
Ag_1min = Ag_1min[~np.isnan(Ag_1min)]

#convert to log scale
Ag_1_ln = np.log(Ag_1min)#-bksubtrt

# 1 minute trial times
t1 = np.array(data['t1'])
t1 = t1[~np.isnan(t1)]

plt.plot(t1,Ag_1_ln, 'y.') 

plt.ylabel('Count Rate',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

#little t parameters
lttet = t1[0:16]
lttey = Ag_1_ln[0:16]

print(curve_fit(fit,lttet,lttey))

m1 = curve_fit(fit,lttet,lttey)[0][0]
b1 = curve_fit(fit,lttet,lttey)[0][1]

print(curve_fit(fit,lttet,lttey))

newfit1 = np.linspace(0,100,20)

#change big t parameters
bigt = t1[13:37]
bigy = Ag_1_ln[13:37]

m2 = curve_fit(fit,bigt,bigy)[0][0]
b2 = curve_fit(fit,bigt,bigy)[0][1]

print(curve_fit(fit,bigt,bigy))

newfit2 = np.linspace(100,180,20)

plt.plot(newfit1,fit(newfit1,m1,b1),'r-')

plt.plot(newfit2,fit(newfit2,m2,b2),'g-')
#plt.errorbar(t1,Ag_1_ln,xerr = 0,yerr = np.sqrt(Ag_1_ln), fmt = None, color = 'y')

print(1/m1)
print(1/m2)

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
# Out:
# 2.3279018640087674
# (array([-0.02376079,  5.86432122]), array([[ 1.86364940e-06, -8.85233473e-05],
#        [-8.85233473e-05,  5.19492279e-03]]))
# (array([-0.02376079,  5.86432122]), array([[ 1.86364940e-06, -8.85233473e-05],
#        [-8.85233473e-05,  5.19492279e-03]]))
# (array([-0.01174759,  4.83277306]), array([[ 1.34254147e-06, -1.71174037e-04],
#        [-1.71174037e-04,  2.31756219e-02]]))
# -42.08613445759353
# -85.1238751743531
# halflifes
# -29.17188543994772
# -59.003374075439574

# %%
#***********************************************************************
# 20 seconds data
#***********************************************************************


#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#background log scale
bk = np.log(Bkgrd)
bksubtrt = np.mean(bk)

# 20 seconds trial
Ag_20 = np.array(data['20 sec'])
Ag_20 = Ag_20[~np.isnan(Ag_20)]

#convert to log scale
Ag_20_ln = np.log(Ag_20)#-bksubtrt

# 20 seconds trial times
t20s = np.array(data['t20s'])
t20s = t20s[~np.isnan(t20s)]

plt.plot(t20s,Ag_20_ln, 'c.') 

plt.ylabel('Count Rate',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

#little t parameters
lttet = t20s[0:16]
lttey = Ag_20_ln[0:16]

print(curve_fit(fit,lttet,lttey))

m1 = curve_fit(fit,lttet,lttey)[0][0]
b1 = curve_fit(fit,lttet,lttey)[0][1]

print(curve_fit(fit,lttet,lttey))

newfit1 = np.linspace(0,100,20)

#change big t parameters
bigt = t20s[15:42]
bigy = Ag_20_ln[15:42]

m2 = curve_fit(fit,bigt,bigy)[0][0]
b2 = curve_fit(fit,bigt,bigy)[0][1]

print(curve_fit(fit,bigt,bigy))

newfit2 = np.linspace(100,220,20)

plt.plot(newfit1,fit(newfit1,m1,b1),'r-')

plt.plot(newfit2,fit(newfit2,m2,b2),'g-')
#plt.errorbar(t1,Ag_1_ln,xerr = 0,yerr = np.sqrt(Ag_1_ln), fmt = None, color = 'y')

print(1/m1)
print(1/m2)

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
# Out:
# (array([-0.02414272,  5.12100916]), array([[ 1.69544282e-06, -8.05335341e-05],
#        [-8.05335341e-05,  4.72604685e-03]]))
# (array([-0.02414272,  5.12100916]), array([[ 1.69544282e-06, -8.05335341e-05],
#        [-8.05335341e-05,  4.72604685e-03]]))
# (array([-0.01173305,  3.97354515]), array([[ 4.14359563e-06, -6.11180354e-04],
#        [-6.11180354e-04,  9.59760334e-02]]))
# -41.42036118929594
# -85.22930652551283
# halflifes
# -28.71040657613506
# -59.07645351923856

# %%
#***********************************************************************
# 10 minute data -> with corrected background
#***********************************************************************


#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# no nans in the background coincidence
Bkgrd = np.array(data['Background again'])
Bkgrd = Bkgrd[~np.isnan(Bkgrd)]

# no nans in the background time
BGt1 = np.array(data['BGt1'])
BGt1 = BGt1[~np.isnan(BGt1)]

#average the background
avgBk = np.mean(Bkgrd)

# 10 minute trial
Ag_10min = np.array(data['AG10min2'])
Ag_10min = Ag_10min[~np.isnan(Ag_10min)]


# 10 minute trial times
t10 = np.array(data['t102'])
t10 = t10[~np.isnan(t10)]

#corrected counts
crrct = Ag_10min# - avgBk

for i in range(len(crrct)):
    t10[crrct<0] = 0
    crrct[crrct<0] = 0
    t10n = t10[t10>0]
    countn = crrct[crrct>0]
        
#convert to log scale
Ag_10_ln = np.log(countn)

plt.plot(t10n,Ag_10_ln, 'b.') 

plt.ylabel('Count Rate ln$(counts/5s)$',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

def fit(x,m,b):
    return m*x + b

#little t parameters
lttet = t10n[0:20]
lttey = Ag_10_ln[0:20]

print(curve_fit(fit,lttet,lttey))

m1 = curve_fit(fit,lttet,lttey)[0][0]
b1 = curve_fit(fit,lttet,lttey)[0][1]

print(curve_fit(fit,lttet,lttey))

newfit1 = np.linspace(0,100,20)

#change big t parameters
bigt = t10n[20:96]
bigy = Ag_10_ln[20:96]

m2 = curve_fit(fit,bigt,bigy)[0][0]
b2 = curve_fit(fit,bigt,bigy)[0][1]

print(curve_fit(fit,bigt,bigy))

newfit2 = np.linspace(100,600,20)

plt.plot(newfit1,fit(newfit1,m1,b1),'r-',label='$^{110}_{47}Ag$ lifetime slope')

plt.plot(newfit2,fit(newfit2,m2,b2),'g-',label='$^{108}_{47}Ag$ lifetime slope')
#plt.errorbar(t10n,Ag_10_ln,xerr = 0,yerr = np.sqrt(Ag_10_ln), fmt = None, color = 'b')
plt.legend(fontsize=14)

print('lifetimes')
print('short one')
print(1/m1)
print('long one')
print(1/m2)
print('minutes long one')
print(1/(m2*60))


print('charging times')
print(np.exp(b1))
print(np.exp(b2))

print('halflifes')
print(np.log(2)*(1/m1))
print(np.log(2)*(1/m2))
pylab.savefig('10min_lngrph.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# (array([-0.01714027,  5.87096741]), array([[ 5.57138240e-07, -3.20354488e-05],
#        [-3.20354488e-05,  2.30515948e-03]]))
# (array([-0.01714027,  5.87096741]), array([[ 5.57138240e-07, -3.20354488e-05],
#        [-3.20354488e-05,  2.30515948e-03]]))
# (array([-0.00460583,  4.42256995]), array([[ 5.83956331e-08, -1.73727009e-05],
#        [-1.73727009e-05,  5.87095099e-03]]))
# lifetimes
# short one
# -58.342138097118934
# long one
# -217.11602029819497
# minutes long one
# -3.6186003383032497
# charging times
# 354.5918513200739
# 83.31011298971838
# halflifes
# -40.43968852985696
# -150.4933573240897

# %%
#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

#charging times
chrgetme1 = 353.1478665005143
chrgetme2 = 108.48441133115954
#chrgetme1 = 354.3710957351405
#chrgetme2 = 162.24690616001078
#lifetimes
lfetme1 = 53.34524972041847
lfetme2 = 117.98298652836979
#lfetme1 = 49.82225347251332
#lfetme2 = 100.67348349658488
tc = np.linspace(0,600,20)

def charge(tc):
    charging = chrgetme1*(1-np.exp(-tc/lfetme1)) + chrgetme2*(1-np.exp(-tc/lfetme2)) 
    return charging 

def big(tc,td):
    tots = chrgetme1*(1-np.exp(-tc/lfetme1))*np.exp(-td/lfetme1) 
    + chrgetme2*(1-np.exp(-tc/lfetme2))*np.exp(-td/lfetme2)  
    return tots 

# 10 minute trial
Ag_10min = np.array(data['AG 10 min'])
Ag_10min = Ag_10min[~np.isnan(Ag_10min)]

# 10 minute trial times
t10 = np.array(data['t10'])
t10 = t10[~np.isnan(t10)]

# 5 minute trial
Ag_5min = np.array(data['Ag 5min'])
Ag_5min = Ag_5min[~np.isnan(Ag_5min)]

# 5 minute trial times 
t5 = np.array(data['t5'])
t5 = t5[~np.isnan(t5)]

# 2 minute trial counts
Ag_2min = np.array(data['Ag 2min'])
Ag_2min = Ag_2min[~np.isnan(Ag_2min)]

# 2 minute trial times
t2 = np.array(data['t2'])
t2 = t2[~np.isnan(t2)]

# 1 minute trial counts
Ag_1min = np.array(data['Ag 1min'])
Ag_1min = Ag_1min[~np.isnan(Ag_1min)]

# 1 minute trial times
t1 = np.array(data['t1'])
t1 = t1[~np.isnan(t1)]

# 20 seconds trial counts
Ag_20 = np.array(data['20 sec'])
Ag_20 = Ag_20[~np.isnan(Ag_20)]
 
# 20 seconds trial times
t20s = np.array(data['t20s'])
t20s = t20s[~np.isnan(t20s)]  

# 10 seconds trial counts
Ag_10 = np.array(data['10 sec'])
Ag_10 = Ag_10[~np.isnan(Ag_10)]

# 10 seconds trial times
t10s = np.array(data['Auto'])
t10s = t10s[~np.isnan(t10s)]  
  
td1 = np.linspace(-13.5,900,30)
discharging = chrgetme1*np.exp(-td1/lfetme1) + chrgetme2*np.exp(-td1/lfetme2) 

td = np.linspace(0,900,30)
discharging = chrgetme1*np.exp(-td/lfetme1) + chrgetme2*np.exp(-td/lfetme2) 

td3 = np.linspace(-9,900,30)
discharging = chrgetme1*np.exp(-td3/lfetme1) + chrgetme2*np.exp(-td3/lfetme2) 

td4 = np.linspace(-14.5,900,30)
discharging = chrgetme1*np.exp(-td4/lfetme1) + chrgetme2*np.exp(-td4/lfetme2) 

#plots
plt.ylabel('Count Rate $(counts/5s)$',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)
plt.plot(tc,charge(tc),'k-',label='Charging time curve')
plt.plot(t10+600,Ag_10min,'b.',label='10 Minute Charging Time')
plt.plot(td4+600,big(600,td4),'b--')
plt.plot(t5+300,Ag_5min,'m.',label='5 Minute Charging Time')
plt.plot(td1+300,big(300,td1),'m--')
plt.plot(t2+120,Ag_2min,'g.',label='2 Minute Charging Time')
plt.plot(td3+120,big(120,td3),'g--')
plt.plot(t1+60,Ag_1min,'y.',label='1 Minute Charging Time')
plt.plot(td1+60,big(60,td),'y--')
plt.plot(t20s+20,Ag_20, 'c.',label='20 Second Charging Time')  
plt.plot(td+20,big(20,td),'c--')
plt.plot(t10s+10,Ag_10, 'r.',label='10 Second Charging Time')
plt.plot(td+10,big(10,td),'r--')

#error bars
plt.errorbar(t10+600,Ag_10min,xerr = 0,yerr = np.sqrt(Ag_10min), fmt = None, color = 'b')
plt.errorbar(t5+300,Ag_5min,xerr = 0,yerr = np.sqrt(Ag_5min), fmt = None, color = 'm')
plt.errorbar(t2+120,Ag_2min,xerr = 0,yerr = np.sqrt(Ag_2min), fmt = None, color = 'g')
plt.errorbar(t1+60,Ag_1min,xerr = 0,yerr = np.sqrt(Ag_1min), fmt = None, color = 'y')
plt.errorbar(t20s+20,Ag_20,xerr = 0,yerr = np.sqrt(Ag_20), fmt = None, color = 'c')
plt.errorbar(t10s+10,Ag_10,xerr = 0,yerr = np.sqrt(Ag_10), fmt = None, color = 'r')

plt.legend(fontsize=12)
pylab.savefig('supergraph.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# /Users/kaylarodriguez/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:2813: MatplotlibDeprecationWarning: Use of None object as fmt keyword argument to suppress plotting of data values is deprecated since 1.4; use the string "none" instead.
#   warnings.warn(msg, mplDeprecation, stacklevel=1)

# %%
#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

shelf = np.array([17,27,36,45,55])
sums = np.array([279,136,91,57,41])/30

def fit(x,A,L):
    return A*np.exp(-x/L)

nwshlf = np.linspace(0,60,20)

print(curve_fit(fit,shelf,sums))

A = curve_fit(fit,shelf,sums)[0][0]
L = curve_fit(fit,shelf,sums)[0][1]

plt.plot(nwshlf,fit(nwshlf,A,L))

plt.plot(shelf,sums,'ro')
plt.ylabel('Number of Particles Detected',fontsize=16)
plt.xlabel('Distance from the Geiger Counter(mm)', fontsize=16)
plt.errorbar(shelf,sums,xerr = 0,yerr = 1, fmt = None, color = 'r',capsize=5)

pylab.savefig('shielding1.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# (array([24.84277163, 16.94287873]), array([[ 7.43999961, -3.55547484],
#        [-3.55547484,  1.91277729]]))
# /Users/kaylarodriguez/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:2813: MatplotlibDeprecationWarning: Use of None object as fmt keyword argument to suppress plotting of data values is deprecated since 1.4; use the string "none" instead.
#   warnings.warn(msg, mplDeprecation, stacklevel=1)

# %%
#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

sum1 = np.array([126,96,48,23,12])
shelf = np.array([0.008,0.02,0.062,0.125,0.25])*25.4
sums = np.array([126,96,48,23,12])/30
error = np.sqrt(sum1)/30
print(error)
def fit(x,A,L):
    return A*np.exp(-x/L)

nwshlf = np.linspace(0,10,50)

print(curve_fit(fit,shelf,sums))

A = curve_fit(fit,shelf,sums)[0][0]
L = curve_fit(fit,shelf,sums)[0][1]

plt.plot(nwshlf,fit(nwshlf,A,L))
plt.plot(shelf,sums,'ro')
plt.ylabel('Number of Particles Detected',fontsize=16)
plt.xlabel('Thickness of the Shielding(mm)', fontsize=16)
plt.errorbar(shelf,sums,xerr = 0,yerr = error, fmt = None, color = 'r',capsize=5)

print(A)
print(L)
print(error)
pylab.savefig('shielding.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# [0.37416574 0.32659863 0.23094011 0.15986105 0.11547005]
# (array([4.60721172, 1.59374256]), array([[ 0.07612626, -0.04149396],
#        [-0.04149396,  0.04737617]]))
# 4.60721171591961
# 1.593742555397701
# [0.37416574 0.32659863 0.23094011 0.15986105 0.11547005]
# /Users/kaylarodriguez/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:2813: MatplotlibDeprecationWarning: Use of None object as fmt keyword argument to suppress plotting of data values is deprecated since 1.4; use the string "none" instead.
#   warnings.warn(msg, mplDeprecation, stacklevel=1)

# %%
#Libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
from scipy.optimize import curve_fit
import pandas as pd
import math

#formatting graphs 
pylab.rcParams['figure.figsize'] = 7,7/1.62
pylab.rcParams['figure.autolayout'] = False
pylab.rcParams.update({'axes.labelsize': 20})
pylab.rcParams.update({'xtick.labelsize': 15})
pylab.rcParams.update({'ytick.labelsize': 15})
pylab.rcParams.update({'lines.linewidth': 1.0})
pylab.rcParams.update({'axes.titlesize': 20.0})

pylab.rcParams.update({'ytick.direction': 'in'}) 
pylab.rcParams.update({'xtick.major.size': 7})   
pylab.rcParams.update({'xtick.direction': 'in'}) 
pylab.rcParams.update({'xtick.top': True}) 
pylab.rcParams.update({'xtick.minor.bottom': True}) 

#reading data from a file
data = pd.read_csv("~/Desktop//RadioactivityData.csv", header=0)

# 10 minute trial
Ag_10min = np.array(data['AG 10 min'])
Ag_10min = Ag_10min[~np.isnan(Ag_10min)]

# 10 minute trial times
t10 = np.array(data['t10'])
t10 = t10[~np.isnan(t10)]

# 5 minute trial
Ag_5min = np.array(data['Ag 5min'])
Ag_5min = Ag_5min[~np.isnan(Ag_5min)]

# 5 minute trial times 
t5 = np.array(data['t5'])
t5 = t5[~np.isnan(t5)]

# 2 minute trial counts
Ag_2min = np.array(data['Ag 2min'])
Ag_2min = Ag_2min[~np.isnan(Ag_2min)]

# 2 minute trial times
t2 = np.array(data['t2'])
t2 = t2[~np.isnan(t2)]

# 1 minute trial counts
Ag_1min = np.array(data['Ag 1min'])
Ag_1min = Ag_1min[~np.isnan(Ag_1min)]

# 1 minute trial times
t1 = np.array(data['t1'])
t1 = t1[~np.isnan(t1)]

# 20 seconds trial counts
Ag_20 = np.array(data['20 sec'])
Ag_20 = Ag_20[~np.isnan(Ag_20)]
 
# 20 seconds trial times
t20s = np.array(data['t20s'])
t20s = t20s[~np.isnan(t20s)]  

# 10 seconds trial counts
Ag_10 = np.array(data['10 sec'])
Ag_10 = Ag_10[~np.isnan(Ag_10)]

# 10 seconds trial times
t10s = np.array(data['Auto'])
t10s = t10s[~np.isnan(t10s)]  



#creating arrays
charge3 = np.array([Ag_10min[0],Ag_5min[0],Ag_2min[0],Ag_1min[0],Ag_20[0],Ag_10[0]])
times = np.array([600,300,120,60,20,10]) 



#charging times
chrgetme1 = 353.1478665005143
chrgetme2 = 108.48441133115954
#chrgetme1 = 354.3710957351405
#chrgetme2 = 162.24690616001078
#lifetimes
lfetme1 = 53.34524972041847
lfetme2 = 117.98298652836979
#lfetme1 = 49.82225347251332
#lfetme2 = 100.67348349658488

td =5
tC = np.linspace(0,600,20)

def charge(tc):
    return (chrgetme1*lfetme1/td)*(1-np.exp(-tc/lfetme1))*(1-np.exp(-td/lfetme1))+(chrgetme2*lfetme2/td)*(1-np.exp(-tc/lfetme2))*(1-np.exp(-td/lfetme2))

def big(tC,td):
    tots = chrgetme1*(1-np.exp(-tC/lfetme1))*np.exp(-td/lfetme1) 
    + chrgetme2*(1-np.exp(-tC/lfetme2))*np.exp(-td/lfetme2)  
    return tots 

charge2 = (charge(600),charge(300),charge(120),charge(60),charge(20),charge(10))

#plots
plt.ylabel('Counts ',fontsize=16)
plt.xlabel('Time (s)', fontsize=16)

plt.plot(tC,charge(tC),'k-', label='theoretical charging curve')
plt.plot(times[0],charge2[0],'ro')
plt.plot(times[1],charge2[1],'ro')
plt.plot(times[2],charge2[2],'ro')
plt.plot(times[3],charge2[3],'ro')
plt.plot(times[4],charge2[4],'ro')
plt.plot(times[5],charge2[5],'ro')
#plt.plot(times[6],charge2[6],'ro')
plt.errorbar(times,charge2,xerr = 0,yerr = 25, fmt = None, color = 'r',capsize=5)


pylab.savefig('charging.pdf', format='pdf', dpi=1000,bbox_inches='tight')
# Out:
# /Users/kaylarodriguez/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:2813: MatplotlibDeprecationWarning: Use of None object as fmt keyword argument to suppress plotting of data values is deprecated since 1.4; use the string "none" instead.
#   warnings.warn(msg, mplDeprecation, stacklevel=1)
